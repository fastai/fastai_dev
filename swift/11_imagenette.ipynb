// %%
%install-location $cwd/swift-install
%install '.package(path: "$cwd/FastaiNotebook_10_mixup_ls")' FastaiNotebook_10_mixup_ls
// Out:
// Installing packages:
// 	.package(path: "/home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls")
// 		FastaiNotebook_10_mixup_ls
// With SwiftPM flags: []
// Working in: /tmp/tmpj73jn29z/swift-install
// /home/sgugger/swift/usr/bin/swift-build: /home/sgugger/anaconda3/lib/libcurl.so.4: no version information available (required by /home/sgugger/swift/usr/lib/swift/linux/libFoundationNetworking.so)
// /home/sgugger/git/fastai_dev/swift/swift-install/package: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_07_batchnorm: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_06_cuda: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_05b_early_stopping: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_05_anneal: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_04_callbacks: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_03_minibatch_training: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_02a_why_sqrt5: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_02_fully_connected: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_01a_fastai_layers: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_01_matmul: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_00_load_data: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/swift-install/package/.build/checkouts/Path.swift: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/swift-install/package/.build/checkouts/Just: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/git/fastai_dev/swift/swift-install/package/.build/checkouts/NotebookExport: warning: /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)[1/18] Compiling FastaiNotebook_08_data_block 01_matmul.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [2/18] Compiling FastaiNotebook_08_data_block 02_fully_connected.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [3/18] Compiling FastaiNotebook_08_data_block 03_minibatch_training.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [4/18] Compiling FastaiNotebook_08_data_block 05b_early_stopping.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [5/18] Compiling FastaiNotebook_08_data_block 06_cuda.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [6/18] Compiling FastaiNotebook_08_data_block 05_anneal.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [7/18] Compiling FastaiNotebook_08_data_block 02a_why_sqrt5.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [8/18] Compiling FastaiNotebook_08_data_block 00_load_data.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [9/18] Compiling FastaiNotebook_08_data_block 04_callbacks.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/04_callbacks.swift:98:61: warning: '@nondiff' is deprecated; use '@noDerivative' instead
//         public typealias F = @differentiable (Model.Output, @nondiff Label) -> Loss
//                                                             ^
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/04_callbacks.swift:162:48: warning: 'valueWithGradient(in:)' is deprecated: Method-style differential operators are deprecated and will be removed; use top-level function 'TensorFlow.valueWithGradient(at:in:)' instead
//         (currentLoss, currentGradient) = model.valueWithGradient { model -> Loss in
//                                                ^
// [10/18] Compiling FastaiNotebook_08_data_block 08_data_block.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// [11/18] Compiling FastaiNotebook_08_data_block 01a_fastai_layers.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [12/18] Compiling FastaiNotebook_08_data_block 07_batchnorm.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08_data_block/Sources/FastaiNotebook_08_data_block/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [13/19] Merging module FastaiNotebook_08_data_block
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)[14/19] Wrapping AST for FastaiNotebook_08_data_block for debugging
// [15/20] Compiling FastaiNotebook_08a_heterogeneous_dictionary 08_data_block.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// [16/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 02_fully_connected.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [17/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 03_minibatch_training.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [18/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 05b_early_stopping.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [19/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 06_cuda.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [20/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 05_anneal.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [21/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 02a_why_sqrt5.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [22/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 00_load_data.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [23/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 04_callbacks.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/04_callbacks.swift:98:61: warning: '@nondiff' is deprecated; use '@noDerivative' instead
//         public typealias F = @differentiable (Model.Output, @nondiff Label) -> Loss
//                                                             ^
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/04_callbacks.swift:162:48: warning: 'valueWithGradient(in:)' is deprecated: Method-style differential operators are deprecated and will be removed; use top-level function 'TensorFlow.valueWithGradient(at:in:)' instead
//         (currentLoss, currentGradient) = model.valueWithGradient { model -> Loss in
//                                                ^
// [24/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 01a_fastai_layers.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [25/30] Compiling FastaiNotebook_08a_heterogeneous_dictionary 07_batchnorm.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_08a_heterogeneous_dictionary/Sources/FastaiNotebook_08a_heterogeneous_dictionary/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [26/31] Merging module FastaiNotebook_08a_heterogeneous_dictionary
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)[27/31] Wrapping AST for FastaiNotebook_08a_heterogeneous_dictionary for debugging
// [28/32] Compiling FastaiNotebook_09_optimizer 08_data_block.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// [29/43] Compiling FastaiNotebook_09_optimizer 02_fully_connected.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [30/43] Compiling FastaiNotebook_09_optimizer 03_minibatch_training.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [31/43] Compiling FastaiNotebook_09_optimizer 05b_early_stopping.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [32/43] Compiling FastaiNotebook_09_optimizer 06_cuda.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [33/43] Compiling FastaiNotebook_09_optimizer 05_anneal.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [34/43] Compiling FastaiNotebook_09_optimizer 02a_why_sqrt5.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [35/43] Compiling FastaiNotebook_09_optimizer 00_load_data.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [36/43] Compiling FastaiNotebook_09_optimizer 04_callbacks.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/04_callbacks.swift:98:61: warning: '@nondiff' is deprecated; use '@noDerivative' instead
//         public typealias F = @differentiable (Model.Output, @nondiff Label) -> Loss
//                                                             ^
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/04_callbacks.swift:162:48: warning: 'valueWithGradient(in:)' is deprecated: Method-style differential operators are deprecated and will be removed; use top-level function 'TensorFlow.valueWithGradient(at:in:)' instead
//         (currentLoss, currentGradient) = model.valueWithGradient { model -> Loss in
//                                                ^
// [37/43] Compiling FastaiNotebook_09_optimizer 01a_fastai_layers.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [38/43] Compiling FastaiNotebook_09_optimizer 07_batchnorm.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [39/43] Compiling FastaiNotebook_09_optimizer 09_optimizer.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_09_optimizer/Sources/FastaiNotebook_09_optimizer/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [40/44] Merging module FastaiNotebook_09_optimizer
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)[41/44] Wrapping AST for FastaiNotebook_09_optimizer for debugging
// [42/45] Compiling FastaiNotebook_10_mixup_ls 08_data_block.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// [43/57] Compiling FastaiNotebook_10_mixup_ls 02_fully_connected.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [44/57] Compiling FastaiNotebook_10_mixup_ls 03_minibatch_training.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [45/57] Compiling FastaiNotebook_10_mixup_ls 05b_early_stopping.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [46/57] Compiling FastaiNotebook_10_mixup_ls 06_cuda.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [47/57] Compiling FastaiNotebook_10_mixup_ls 05_anneal.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [48/57] Compiling FastaiNotebook_10_mixup_ls 02a_why_sqrt5.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [49/57] Compiling FastaiNotebook_10_mixup_ls 00_load_data.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [50/57] Compiling FastaiNotebook_10_mixup_ls 04_callbacks.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/04_callbacks.swift:98:61: warning: '@nondiff' is deprecated; use '@noDerivative' instead
//         public typealias F = @differentiable (Model.Output, @nondiff Label) -> Loss
//                                                             ^
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/04_callbacks.swift:162:48: warning: 'valueWithGradient(in:)' is deprecated: Method-style differential operators are deprecated and will be removed; use top-level function 'TensorFlow.valueWithGradient(at:in:)' instead
//         (currentLoss, currentGradient) = model.valueWithGradient { model -> Loss in
//                                                ^
// [51/57] Compiling FastaiNotebook_10_mixup_ls 01a_fastai_layers.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [52/57] Compiling FastaiNotebook_10_mixup_ls 07_batchnorm.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/07_batchnorm.swift:134:51: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(wrt: (x, scale, offset), vjp: _vjpFusedBatchNorm)
//                                                   ^~~~~~~~~~~~~~~~~~
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [53/57] Compiling FastaiNotebook_10_mixup_ls 09_optimizer.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [54/57] Compiling FastaiNotebook_10_mixup_ls 10_mixup_ls.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/git/fastai_dev/swift/FastaiNotebook_10_mixup_ls/Sources/FastaiNotebook_10_mixup_ls/01a_fastai_layers.swift:48:26: warning: 'jvp:' and 'vjp:' arguments in '@differentiable' attribute are deprecated; use '@derivative' attribute for derivative registration instead
//     @differentiable(vjp: callGrad)
//                          ^~~~~~~~
// [55/58] Merging module FastaiNotebook_10_mixup_ls
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)[56/59] Wrapping AST for FastaiNotebook_10_mixup_ls for debugging
// [57/59] Compiling jupyterInstalledPackages jupyterInstalledPackages.swift
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// [58/60] Merging module jupyterInstalledPackages
// /home/sgugger/swift/usr/bin/swift: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift)
// /home/sgugger/swift/usr/bin/swiftc: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swiftc)
// /home/sgugger/swift/usr/bin/swift-autolink-extract: /home/sgugger/anaconda3/lib/libuuid.so.1: no version information available (required by /home/sgugger/swift/usr/bin/swift-autolink-extract)
// [59/59] Linking libjupyterInstalledPackages.so
// Initializing Swift...
// Installation complete!

// %%
// export
import Path
import TensorFlow

// %%
import FastaiNotebook_10_mixup_ls

// %%
%include "EnableIPythonDisplay.swift"
IPythonDisplay.shell.enable_matplotlib("inline")
// Out:
// ('inline', 'module://ipykernel.pylab.backend_inline')

// %% [markdown]
// ## Load data

// %%
let path = downloadImagenette()

// %%
let il = ItemList(fromFolder: path, extensions: ["jpeg", "jpg"])

// %% [markdown]
// Then we split them according to the grandparent folder. `train` for the training set (which is the default) and `val` for the validation set.

// %%
let sd = SplitData(il) {grandParentSplitter(fName: $0, valid: "val")}

// %% [markdown]
// We define our processors for the training set and the validation set. The difference with python is that we have to specify a noop processor (with a type) when we don't want to do anything.

// %%
var procLabel = CategoryProcessor()

// %% [markdown]
// Then we can label our data using the parent directory and those two processors.

// %%
let sld = makeLabeledData(sd, fromFunc: parentLabeler, procLabel: &procLabel)

// %% [markdown]
// We can then convert to a databunch by specifying two function that will convert our items and our labels to `Tensor`. For the items we use `pathsToTensor` that converts the `Path` object to their string representation then `StringTensor`. For the labels,  the function `intsToTensor` just convert the indices we have in proper tensors.

// %%
let rawData = sld.toDataBunch(itemToTensor: pathsToTensor, labelToTensor: intsToTensor, bs: 128)

// %% [markdown]
// The main difference with python is that the transforms are all applied directly on the datasets by `tf.data`. Even opening on the image is such a transform, that will take a `StringTensor` and return a tensor of `UInt8`. We have written a function that opens the image in a filename and returns it decoded and resized to `size`, which is the transform we apply to our items.

// %%
let data = transformData(rawData) { openAndResize(fname: $0, size: 128) }

// %% [markdown]
// We can then have a look by grabbing one batch.

// %%
let batch = data.train.oneBatch()!

// %% [markdown]
// Our batches have two attributes `xb` and `yb` that contain the inputs and targets respectively.

// %%
print(batch.xb.shape)
print(batch.yb.shape)
// Out:
// [128, 128, 128, 3]
// [128]

// %% [markdown]
// If we decode the labels suing our processor, we can plot images with their corresponding classes:

// %%
let labels = batch.yb.scalars.map { procLabel.vocab![Int($0)] }
showImages(batch.xb, labels: labels)

// %% [markdown]
// ## XResnet

// %% [markdown]
// We build the same xresnet we had in fastai over PyTorch. Modules in S4TF are `struct` that conform to the `Layer` protocol. You define any layer it uses as attributes that you have to properly set in the `init` function. The equivalent of `forward` in PyTorch is `callAsFunction`.
//
// We are using our custom fastai layers that have the prefix `FA` because they contain experimental features that might eventually be merged in S4TF. There is a NoBiasConv layer separate from the Conv Layer because S4TF doesn't yet support control flow. That means you can't have if statements or for loops in the `callAsFunction` function.

// %%
//export
public struct ConvLayer: Layer {
    public var bn: FABatchNorm<Float>
    public var conv: FANoBiasConv2D<Float>
    
    public init(_ cIn: Int, _ cOut: Int, ks: Int = 3, stride: Int = 1, zeroBn: Bool = false, act: Bool = true){
        bn = FABatchNorm(featureCount: cOut)
//      "activation: act ? relu : identity" fails on 0.3.1, so we use if/else
        if act {conv = FANoBiasConv2D(cIn, cOut, ks: ks, stride: stride, activation: relu)}
        else   {conv = FANoBiasConv2D(cIn, cOut, ks: ks, stride: stride, activation: identity)}
        if zeroBn { bn.scale = Tensor(zeros: [cOut]) }
    }
    
    @differentiable
    public func callAsFunction(_ input: TF) -> TF {
        // TODO: Work around https://bugs.swift.org/browse/TF-606
        return bn.forward(conv.forward(input))
    }
}

// %% [markdown]
// However we will need some optional layers to have refactored resnet implementation: in the shortcuts, we sometimes apply an average pool or a convolution layer, but most of the time we don't do anything. To be able to have that in S4TF, we write a customized protocol called `SwitchableLayer`. It inherits from `Layer` and adds a boolean `isOn` and a differentiable `forward` function. A structure conforming to it will return the result of `forward` if `isOn` is `true`, otherwise it won't do anything.
//
// As we said before, Swift autodiff doesn't support control flow (yet), so `if` statements aren't differentiable. That doesn't stop us from doing interesting work though, because we can create a custom function that will manually compute the gradients of our switchable layer:

// %%
//export
//A layer that you can switch off to do the identity instead
public protocol SwitchableLayer: Layer {
    associatedtype Input
    var isOn: Bool { get set }
    
    @differentiable func forward(_ input: Input) -> Input
}

public extension SwitchableLayer {
    func callAsFunction(_ input: Input) -> Input {
        return isOn ? forward(input) : input
    }

    @differentiating(callAsFunction)
    func gradForward(_ input: Input) ->
           (value: Input,
            pullback: (Self.Input.TangentVector) ->
                                  (Self.TangentVector, Self.Input.TangentVector)) {
        if isOn {
            return valueWithPullback(at: input) { $0.forward($1) } 
        } else {
            return (input, { (Self.TangentVector.zero, $0) }) 
        }
    }
}

// %% [markdown]
// Then we use this protocol to create a `MaybeAvgPool2D` layer and a `MaybeConv` layer. The little downside is that we will have to create a fake convolution for the `MaybeConv` that are just identity, but we will just create a 1x1x1x1 weight matrix so that it doesn't take much memory.

// %%
//export
public struct MaybeAvgPool2D: ParameterlessLayer {
    @noDerivative let poolSize: (Int, Int, Int, Int)
    @noDerivative let strides: (Int, Int, Int, Int)
    @noDerivative let padding: Padding
    @noDerivative public var isOn: Bool
    
    @differentiable public func callAsFunction(_ input: TF) -> TF { 
        return isOn ? avgPool2D(input, filterSize: poolSize, strides: strides, padding: padding) : input
    }
    
    public init(_ sz: Int, padding: Padding = .valid) {
        isOn = (sz>1)
        poolSize = (1, sz, sz, 1)
        strides = (1, sz, sz, 1)
        self.padding = padding
    }
}

// %%
//export
public struct MaybeConv: Layer {
    var conv: ConvLayer
    @noDerivative public var isOn: Bool
    
    @differentiable public func callAsFunction(_ input: TF) -> TF { 
        return isOn ? conv(input) : input
    }
    
    public init(_ cIn: Int, _ cOut: Int) {
        isOn = (cIn > 1) || (cOut > 1)
        conv = ConvLayer(cIn, cOut, ks: 1, act: false)
    }
}

// %% [markdown]
// With those two maybe layers, we can write a `ResBlock` as we are used to. We can have array of layers that have the same type, and such an array can be treated as if it was a normal layer.

// %%
//export
public struct ResBlock: Layer {
    public var convs: [ConvLayer]
    public var idConv: MaybeConv
    public var pool: MaybeAvgPool2D
    
    public init(_ expansion: Int, _ ni: Int, _ nh: Int, stride: Int = 1){
        let (nf, nin) = (nh*expansion,ni*expansion)
        convs = (expansion==1) ? [
            ConvLayer(nin, nh, ks: 3, stride: stride),
            ConvLayer(nh, nf, ks: 3, zeroBn: true, act: false)
        ] : [
            ConvLayer(nin, nh, ks: 1),
            ConvLayer(nh, nh, ks: 3, stride: stride),
            ConvLayer(nh, nf, ks: 1, zeroBn: true, act: false)
        ]
        idConv = nin==nf ? MaybeConv(1,1) : MaybeConv(nin, nf)
        pool = MaybeAvgPool2D(stride)
    }
    
    @differentiable
    public func callAsFunction(_ inp: TF) -> TF {
        return relu(convs(inp) + idConv(pool(inp)))
    }
    
}

// %% [markdown]
// Then we can create our `XResnet` pretty much the same way as in pytorch. The list comprehesions are replaced by uses of `map` or `reduce`. The `makeLayer` function is out side of the `XResNet` structure because it can't be used in the `init` otherwise (in swift, you can only use self in the init when all the attributes have been properly set, and this `makeLayer` function is used to create the attribute `blocks`).

// %%
//export
func makeLayer(_ expansion: Int, _ ni: Int, _ nf: Int, _ nBlocks: Int, stride: Int) -> [ResBlock] {
    return Array(0..<nBlocks).map { ResBlock(expansion, $0==0 ? ni : nf, nf, stride: $0==0 ? stride : 1) }
}

// %%
//export
public struct XResNet: Layer {
    public var stem: [ConvLayer]
    public var maxPool = MaxPool2D<Float>(poolSize: (3,3), strides: (2,2), padding: .same)
    public var blocks: [ResBlock]
    public var pool = GlobalAvgPool2D<Float>()
    public var linear: Dense<Float>
    
    public init(_ expansion: Int, _ layers: [Int], cIn: Int = 3, cOut: Int = 1000){
        var nfs = [cIn, (cIn+1)*8, 64, 64]
        stem = (0..<3).map{ ConvLayer(nfs[$0], nfs[$0+1], stride: $0==0 ? 2 : 1)}
        nfs = [64/expansion,64,128,256,512]
        blocks = layers.enumerated().map { (i,l) in 
            return makeLayer(expansion, nfs[i], nfs[i+1], l, stride: i==0 ? 1 : 2)
        }.reduce([], +)
        linear = Dense(inputSize: nfs.last!*expansion, outputSize: cOut)
    }
    
    @differentiable
    public func callAsFunction(_ inp: TF) -> TF {
        return inp.compose(stem, maxPool, blocks, pool, linear)
    }
}

// %%
//export
public func xresnet18 (cIn: Int = 3, cOut: Int = 1000) -> XResNet { return XResNet(1, [2, 2, 2, 2], cIn: cIn, cOut: cOut) }
public func xresnet34 (cIn: Int = 3, cOut: Int = 1000) -> XResNet { return XResNet(1, [3, 4, 6, 3], cIn: cIn, cOut: cOut) }
public func xresnet50 (cIn: Int = 3, cOut: Int = 1000) -> XResNet { return XResNet(4, [3, 4, 6, 3], cIn: cIn, cOut: cOut) }
public func xresnet101(cIn: Int = 3, cOut: Int = 1000) -> XResNet { return XResNet(4, [3, 4, 23, 3], cIn: cIn, cOut: cOut) }
public func xresnet152(cIn: Int = 3, cOut: Int = 1000) -> XResNet { return XResNet(4, [3, 8, 36, 3], cIn: cIn, cOut: cOut) }

// %% [markdown]
// To define a `Learner` we need our data, a model initializer function, and optimizer initializer function and a loss function. The model initilializer is a simple closure that returns the model.

// %%
func modelInit() -> XResNet { return xresnet18(cOut: 10) }

// %% [markdown]
// The optimizer function is a convenience function we wrote in notebook 09 (like we had done in the python version) that returns a `StatefulOptimizer` with all the necessary stats/step delegates.

// %%
let optFunc: (XResNet) -> StatefulOptimizer<XResNet> = adamOpt(lr: 1e-3, mom: 0.9, beta: 0.99, wd: 1e-2, eps: 1e-6)

// %% [markdown]
// Then we can create our `Learner`. The loss function is the classic cross entropy + softmax, and is given by S4TF.

// %%
let learner = Learner(data: data, lossFunc: crossEntropy, optFunc: optFunc, modelInit: modelInit)

// %% [markdown]
// In swift, callbacks are called delegates. We have written a convenience function to automatically add the basic ones we need (train/eval, the recorder, metrics progress bar). This function returns the `recorder` if we want to look at losses or do some plots later.
//
// Then we add the delegate to normalize our inputs with the statistics of ImageNet.

// %%
let recorder = learner.makeDefaultDelegates(metrics: [accuracy])
learner.addDelegate(learner.makeNormalize(mean: imagenetStats.mean, std: imagenetStats.std))

// %% [markdown]
// Then we can fit with the 1cycle policy:

// %%
learner.addOneCycleDelegates(1e-3, pctStart: 0.5)
learner.fit(5)
// Out:
// Epoch 0: [1.5330061, 0.5011465]
// Epoch 1: [1.1052388, 0.6481529]
// Epoch 2: [0.9177423, 0.71031845]
// Epoch 3: [0.69768846, 0.77171975]
// Epoch 4: [0.62863517, 0.7974522]

// %% [markdown]
// ## Export

// %%
import NotebookExport
let exporter = NotebookExport(Path.cwd/"11_imagenette.ipynb")
print(exporter.export(usingPrefix: "FastaiNotebook_"))
// Out:
// success
