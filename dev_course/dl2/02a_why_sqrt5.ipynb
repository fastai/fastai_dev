# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# ## Does nn.Conv2d init work well?

# %% [markdown]
# [Jump_to lesson 9 video](https://youtu.be/AcA8HAYh7IE?t=21)

# %%
#export
from exp.nb_02 import *

def get_data():
    path = datasets.download_data(MNIST_URL, ext='.gz')
    with gzip.open(path, 'rb') as f:
        ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding='latin-1')
    return map(tensor, (x_train,y_train,x_valid,y_valid))

def normalize(x, m, s): return (x-m)/s
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-529fb1642076> in <module>
#       1 #export
# ----> 2 from exp.nb_02 import *
#       3
#       4 def get_data():
#       5     path = datasets.download_data(MNIST_URL, ext='.gz')
#
# ModuleNotFoundError: No module named 'exp'

# %%
torch.nn.modules.conv._ConvNd.reset_parameters??

# %%
x_train,y_train,x_valid,y_valid = get_data()
train_mean,train_std = x_train.mean(),x_train.std()
x_train = normalize(x_train, train_mean, train_std)
x_valid = normalize(x_valid, train_mean, train_std)

# %%
x_train = x_train.view(-1,1,28,28)
x_valid = x_valid.view(-1,1,28,28)
x_train.shape,x_valid.shape
# Out:
# (torch.Size([50000, 1, 28, 28]), torch.Size([10000, 1, 28, 28]))

# %%
n,*_ = x_train.shape
c = y_train.max()+1
nh = 32
n,c
# Out:
# (50000, tensor(10))

# %%
l1 = nn.Conv2d(1, nh, 5)

# %%
x = x_valid[:100]

# %%
x.shape
# Out:
# torch.Size([100, 1, 28, 28])

# %%
def stats(x): return x.mean(),x.std()

# %%
stats(l1.weight),stats(l1.bias)
# Out:
# ((tensor(-0.0014, grad_fn=<MeanBackward0>),
#   tensor(0.1173, grad_fn=<StdBackward0>)),
#  (tensor(0.0088, grad_fn=<MeanBackward0>),
#   tensor(0.1240, grad_fn=<StdBackward0>)))

# %%
t = l1(x)

# %%
stats(t)
# Out:
# (tensor(0.0050, grad_fn=<MeanBackward0>),
#  tensor(0.7291, grad_fn=<StdBackward0>))

# %%
init.kaiming_normal_(l1.weight, a=1.)
stats(l1(x))
# Out:
# (tensor(-0.0038, grad_fn=<MeanBackward0>),
#  tensor(0.9980, grad_fn=<StdBackward0>))

# %%
import torch.nn.functional as F

# %%
def f1(x,a=0): return F.leaky_relu(l1(x),a)

# %%
init.kaiming_normal_(l1.weight, a=0)
stats(f1(x))
# Out:
# (tensor(0.4726, grad_fn=<MeanBackward0>),
#  tensor(0.9197, grad_fn=<StdBackward0>))

# %%
l1 = nn.Conv2d(1, nh, 5)
stats(f1(x))
# Out:
# (tensor(0.2354, grad_fn=<MeanBackward0>),
#  tensor(0.4522, grad_fn=<StdBackward0>))

# %%
l1.weight.shape
# Out:
# torch.Size([32, 1, 5, 5])

# %%
# receptive field size
rec_fs = l1.weight[0,0].numel()
rec_fs
# Out:
# 25

# %%
nf,ni,*_ = l1.weight.shape
nf,ni
# Out:
# (32, 1)

# %%
fan_in  = ni*rec_fs
fan_out = nf*rec_fs
fan_in,fan_out
# Out:
# (25, 800)

# %%
def gain(a): return math.sqrt(2.0 / (1 + a**2))

# %%
gain(1),gain(0),gain(0.01),gain(0.1),gain(math.sqrt(5.))
# Out:
# (1.0,
#  1.4142135623730951,
#  1.4141428569978354,
#  1.4071950894605838,
#  0.5773502691896257)

# %%
torch.zeros(10000).uniform_(-1,1).std()
# Out:
# tensor(0.5753)

# %%
1/math.sqrt(3.)
# Out:
# 0.5773502691896258

# %%
def kaiming2(x,a, use_fan_out=False):
    nf,ni,*_ = x.shape
    rec_fs = x[0,0].shape.numel()
    fan = nf*rec_fs if use_fan_out else ni*rec_fs
    std = gain(a) / math.sqrt(fan)
    bound = math.sqrt(3.) * std
    x.data.uniform_(-bound,bound)

# %%
kaiming2(l1.weight, a=0);
stats(f1(x))
# Out:
# (tensor(0.5222, grad_fn=<MeanBackward0>),
#  tensor(0.9589, grad_fn=<StdBackward0>))

# %%
kaiming2(l1.weight, a=math.sqrt(5.))
stats(f1(x))
# Out:
# (tensor(0.2286, grad_fn=<MeanBackward0>),
#  tensor(0.4020, grad_fn=<StdBackward0>))

# %%
class Flatten(nn.Module):
    def forward(self,x): return x.view(-1)

# %%
m = nn.Sequential(
    nn.Conv2d(1,8, 5,stride=2,padding=2), nn.ReLU(),
    nn.Conv2d(8,16,3,stride=2,padding=1), nn.ReLU(),
    nn.Conv2d(16,32,3,stride=2,padding=1), nn.ReLU(),
    nn.Conv2d(32,1,3,stride=2,padding=1),
    nn.AdaptiveAvgPool2d(1),
    Flatten(),
)

# %%
y = y_valid[:100].float()

# %%
t = m(x)
stats(t)
# Out:
# (tensor(-0.0097, grad_fn=<MeanBackward0>),
#  tensor(0.0060, grad_fn=<StdBackward0>))

# %%
l = mse(t,y)
l.backward()

# %%
stats(m[0].weight.grad)
# Out:
# (tensor(-0.0043), tensor(0.0604))

# %%
init.kaiming_uniform_??

# %%
for l in m:
    if isinstance(l,nn.Conv2d):
        init.kaiming_uniform_(l.weight)
        l.bias.data.zero_()

# %%
t = m(x)
stats(t)
# Out:
# (tensor(0.1581, grad_fn=<MeanBackward0>),
#  tensor(0.2368, grad_fn=<StdBackward0>))

# %%
l = mse(t,y)
l.backward()
stats(m[0].weight.grad)
# Out:
# (tensor(-0.0761), tensor(0.3662))

# %% [markdown]
# ## Export

# %%
# !./notebook2script.py 02_fully_connected.ipynb
# Out:
# Converted 02_fully_connected.ipynb to nb_02.py
