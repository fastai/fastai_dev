# %%
#export
from fastai_local.imports import *
from fastai_local.test import *
from fastai_local.core import *
from fastai_local.data.pipeline import *
from fastai_local.data.source import *
from fastai_local.data.core import *
from fastai.datasets import *

# %%
source = untar_data(URLs.PETS)/"images"

# %%
class PetTfm(Transform):
    def __init__(self, source):
        super().__init__()
        self.source,self.vocab = source,None
        self.labeller = re_labeller(pat = r'/([^/]+)_\d+.jpg$')
    
    def setups(self, dsrc):
        vals = map(self.labeller, dsrc.train)
        self.vocab,self.o2i = uniqueify(vals, sort=True, bidir=True)
        
    def encodes(self, o):
        if self.vocab is None: return o
        return Image.open(o), self.o2i[self.labeller(o)]

    def decodes(self, o): return o[0],self.vocab[o[1]]
    def show(self, o, ax=None): show_image(o[0], ax, title=o[1])

# %%
tfm = PetTfm(source)
items = get_image_files(source)
split_idx = random_splitter()(items)

# %%
pets = DataSource(items, tfm, filts=split_idx)

# %% [markdown]
# To access an element we need to specify index/filter (the latter defaults to 0)

# %%
xy = pets.get(0,1); xy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-41bf645e17e4> in <module>
# ----> 1 xy = pets.get(0,1); xy
#
# ~/git/fastai_docs/dev/fastai_local/data/source.py in get(self, idx, filt)
#      50     def get(self, idx, filt=0):
#      51         "Value(s) at `idx` from filtered subset `filt`"
# ---> 52         it = self.items[self.filts[filt][idx]]
#      53         return [self.tfm(o, filt=filt) for o in it] if is_listy(it) else self.tfm(it, filt=filt)
#      54
#
# ~/git/fastai_docs/dev/fastai_local/data/source.py in __getitem__(self, idx)
#      27     def __eq__(self,b): return all_equal(b,self)
#      28     def __getitem__(self, idx):
# ---> 29         if is_iter(idx): return [self.items[i] for i in mask2idxs(idx)]
#      30         return self.items[idx]
#      31
#
# ~/git/fastai_docs/dev/fastai_local/data/source.py in <listcomp>(.0)
#      27     def __eq__(self,b): return all_equal(b,self)
#      28     def __getitem__(self, idx):
# ---> 29         if is_iter(idx): return [self.items[i] for i in mask2idxs(idx)]
#      30         return self.items[idx]
#      31
#
# TypeError: only integer tensors of a single element can be converted to an index

# %% [markdown]
# We can decode an element for display purposes.

# %%
xyd = pets.decode(xy, 1); xyd
# Out:
# (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F0A1F9BF198>,
#  'japanese_chin')

# %%
tfm.show(xyd)

# %%
# export
def _dsrc_show(self, o, filt=0, **kwargs): self.tfm.show(self.decode(o, filt), **kwargs)
def _fl_show(self, o, **kwargs): self.dsrc.show(o, self.filt, **kwargs)
def _fl_show_at(self, i, **kwargs): self.show(self[i], **kwargs)

DataSource.show = _dsrc_show
FilteredList.show    = _fl_show
FilteredList.show_at = _fl_show_at

# %%
pets.show(pets.get(0,1))

# %%
pets.valid.show_at(0)
