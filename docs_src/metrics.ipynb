# %%
from fastai.gen_doc.gen_notebooks import update_module_metadata
import fastai.metrics
# For updating jekyll metadata. You MUST reload notebook immediately after executing this cell for changes to save
# Leave blank to autopopulate from mod.__doc__
update_module_metadata(fastai.metrics)

# %% [markdown]
# # Training metrics

# %% [markdown]
# *Metrics* for training fastai models are simply functions that take `input` and `target` tensors, and return some metric of interest for training. You can write your own metrics by defining a function of that type, and passing it to [`Learner`](/basic_train.html#Learner) in the [code]metrics[/code] parameter, or use one of the following pre-defined functions.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.metrics import *

# %% [markdown]
# ### Predefined metrics:

# %%
show_doc(accuracy)
# Out:
# #### <a id=accuracy></a>`accuracy`
# `accuracy`(`input`:`Tensor`, `targs`:`Tensor`) -> `OneEltTensor`
#
#
# Accuracy <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L31">[source]</a>

# %%
show_doc(accuracy_thresh)
# Out:
# #### <a id=accuracy_thresh></a>`accuracy_thresh`
# `accuracy_thresh`(`y_pred`:`Tensor`, `y_true`:`Tensor`, `thresh`:`float`=`0.5`, `sigmoid`:`bool`=`True`) -> `OneEltTensor`
# <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L18">[source]</a>

# %% [markdown]
# Accuracy for multi-label models, based on comparing predictions to `thresh`.

# %%
show_doc(dice)
# Out:
# #### <a id=dice></a>`dice`
# `dice`(`input`:`Tensor`, `targs`:`Tensor`) -> `OneEltTensor`
#
#
# Dice coefficient metric for binary target <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L22">[source]</a>

# %%
show_doc(fbeta)
# Out:
# #### <a id=fbeta></a>`fbeta`
# `fbeta`(`y_pred`:`Tensor`, `y_true`:`Tensor`, `thresh`:`float`=`0.5`, `beta`:`float`=`2`, `eps`:`float`=`1e-09`, `sigmoid`:`bool`=`True`) -> `OneEltTensor`
#
#
# Computes the f_beta between preds and targets <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L6">[source]</a>

# %% [markdown]
# See the [F1 score wikipedia page](https://en.wikipedia.org/wiki/F1_score) for details.

# %%
show_doc(exp_rmspe)
# Out:
# #### <a id=exp_rmspe></a>`exp_rmspe`
# `exp_rmspe`(`pred`:`Tensor`, `targ`:`Tensor`) -> `OneEltTensor`
# <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L38">[source]</a>
