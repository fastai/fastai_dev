# %% [markdown]
# # Training metrics

# %% [markdown]
# *Metrics* for training fastai models are simply functions that take `input` and `target` tensors, and return some metric of interest for training. You can write your own metrics by defining a function of that type, and passing it to `Learner` in the [code]metrics[/code] parameter, or use one of the following pre-defined functions.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.metrics import *

# %% [markdown]
# ### Predefined metrics:

# %%
show_doc(accuracy)
# Out:
# #### <a id=accuracy></a>`accuracy`
# > `accuracy`(`input`:`Tensor`, `targs`:`Tensor`) -> `Rank0Tensor`
#
#
# Compute accuracy with `targs` when `input` is bs * n_classes. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L32">[source]</a>
# #### <a id=accuracy></a>`accuracy`
# > `accuracy`(`input`:`Tensor`, `targs`:`Tensor`) -> `Rank0Tensor`
#
#
# Compute accuracy with `targs` when `input` is bs * n_classes. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L32">[source]</a>

# %%
show_doc(accuracy_thresh, doc_string=False)
# Out:
# #### <a id=accuracy_thresh></a>`accuracy_thresh`
# > `accuracy_thresh`(`y_pred`:`Tensor`, `y_true`:`Tensor`, `thresh`:`float`=`0.5`, `sigmoid`:`bool`=`True`) -> `Rank0Tensor`
# <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L18">[source]</a>
# #### <a id=accuracy_thresh></a>`accuracy_thresh`
# > `accuracy_thresh`(`y_pred`:`Tensor`, `y_true`:`Tensor`, `thresh`:`float`=`0.5`, `sigmoid`:`bool`=`True`) -> `Rank0Tensor`
# <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L18">[source]</a>

# %% [markdown]
# Compute accuracy when `y_pred` and `y_true` for multi-label models, based on comparing predictions to `thresh`, `sigmoid` will be applied to `y_pred` if the corresponding flag is True.

# %%
show_doc(dice)
# Out:
# #### <a id=dice></a>`dice`
# > `dice`(`input`:`Tensor`, `targs`:`Tensor`) -> `Rank0Tensor`
#
#
# Dice coefficient metric for binary target. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L23">[source]</a>
# #### <a id=dice></a>`dice`
# > `dice`(`input`:`Tensor`, `targs`:`Tensor`) -> `Rank0Tensor`
#
#
# Dice coefficient metric for binary target. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L23">[source]</a>

# %%
show_doc(fbeta)
# Out:
# #### <a id=fbeta></a>`fbeta`
# > `fbeta`(`y_pred`:`Tensor`, `y_true`:`Tensor`, `thresh`:`float`=`0.5`, `beta`:`float`=`2`, `eps`:`float`=`1e-09`, `sigmoid`:`bool`=`True`) -> `Rank0Tensor`
#
#
# Compute the f_beta between preds and targets. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L6">[source]</a>
# #### <a id=fbeta></a>`fbeta`
# > `fbeta`(`y_pred`:`Tensor`, `y_true`:`Tensor`, `thresh`:`float`=`0.5`, `beta`:`float`=`2`, `eps`:`float`=`1e-09`, `sigmoid`:`bool`=`True`) -> `Rank0Tensor`
#
#
# Compute the f_beta between preds and targets. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L6">[source]</a>

# %% [markdown]
# See the [F1 score wikipedia page](https://en.wikipedia.org/wiki/F1_score) for details.

# %%
show_doc(exp_rmspe)
# Out:
# #### <a id=exp_rmspe></a>`exp_rmspe`
# > `exp_rmspe`(`pred`:`Tensor`, `targ`:`Tensor`) -> `Rank0Tensor`
#
#
# Exp RMSE between `pred` and `targ`. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L39">[source]</a>
# #### <a id=exp_rmspe></a>`exp_rmspe`
# > `exp_rmspe`(`pred`:`Tensor`, `targ`:`Tensor`) -> `Rank0Tensor`
#
#
# Exp RMSE between `pred` and `targ`. <a href="https://github.com/fastai/fastai/blob/master/fastai/metrics.py#L39">[source]</a>
